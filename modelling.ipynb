# %% [markdown]
# ## Data collection and Preliminary Analysis

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
from zipfile import ZipFile

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score






from random import randint





path = "wine+quality.zip"

def view_data(path):

    with ZipFile(path, "r") as f:
        f.printdir()

def load_data(path):
    with ZipFile(path, "r") as zip_data:
        with zip_data.open("winequality-white.csv") as f:
            data_file = pd.read_csv(f, sep=";")
            return data_file

# %%
view_data(path)
# Out:
# File Name                                             Modified             Size
# winequality-red.csv                            2023-05-22 22:24:00        84199
# winequality-white.csv                          2023-05-22 22:24:00       264426
# winequality.names                              2023-05-22 22:24:00         3305

# %%
df = load_data(path)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# ## DATA CLEANING

# %% [markdown]
# ## EDA

# %%
df.describe().T.style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_b2a30_row0_col0, #T_b2a30_row1_col0, #T_b2a30_row1_col1, #T_b2a30_row1_col2, #T_b2a30_row1_col4, #T_b2a30_row1_col5, #T_b2a30_row1_col6, #T_b2a30_row1_col7, #T_b2a30_row2_col0, #T_b2a30_row2_col1, #T_b2a30_row2_col2, #T_b2a30_row2_col3, #T_b2a30_row2_col4, #T_b2a30_row2_col5, #T_b2a30_row2_col6, #T_b2a30_row2_col7, #T_b2a30_row3_col0, #T_b2a30_row4_col0, #T_b2a30_row4_col1, #T_b2a30_row4_col2, #T_b2a30_row4_col3, #T_b2a30_row4_col4, #T_b2a30_row4_col5, #T_b2a30_row4_col6, #T_b2a30_row4_col7, #T_b2a30_row5_col0, #T_b2a30_row6_col0, #T_b2a30_row7_col0, #T_b2a30_row7_col2, #T_b2a30_row7_col7, #T_b2a30_row8_col0, #T_b2a30_row8_col2, #T_b2a30_row9_col0, #T_b2a30_row9_col1, #T_b2a30_row9_col2, #T_b2a30_row9_col4, #T_b2a30_row9_col5, #T_b2a30_row9_col6, #T_b2a30_row9_col7, #T_b2a30_row10_col0, #T_b2a30_row11_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b2a30_row0_col1, #T_b2a30_row0_col5, #T_b2a30_row0_col6, #T_b2a30_row3_col1, #T_b2a30_row11_col4, #T_b2a30_row11_col5 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_b2a30_row0_col2, #T_b2a30_row8_col1, #T_b2a30_row8_col5, #T_b2a30_row11_col2, #T_b2a30_row11_col7 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_b2a30_row0_col3 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_b2a30_row0_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_b2a30_row0_col7, #T_b2a30_row10_col7 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_b2a30_row1_col3, #T_b2a30_row7_col4, #T_b2a30_row8_col7 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_b2a30_row3_col2 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_b2a30_row3_col3, #T_b2a30_row10_col6 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_b2a30_row3_col4, #T_b2a30_row8_col6 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_b2a30_row3_col5, #T_b2a30_row11_col6 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_b2a30_row3_col6 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_b2a30_row3_col7 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_b2a30_row5_col1 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_b2a30_row5_col2 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_b2a30_row5_col3 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_b2a30_row5_col4 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_b2a30_row5_col5 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_b2a30_row5_col6 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_b2a30_row5_col7 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_b2a30_row6_col1, #T_b2a30_row6_col2, #T_b2a30_row6_col3, #T_b2a30_row6_col4, #T_b2a30_row6_col5, #T_b2a30_row6_col6, #T_b2a30_row6_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b2a30_row7_col1, #T_b2a30_row7_col5, #T_b2a30_row7_col6 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_b2a30_row7_col3 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_b2a30_row8_col3 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_b2a30_row8_col4, #T_b2a30_row10_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_b2a30_row9_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_b2a30_row10_col1, #T_b2a30_row10_col5 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_b2a30_row10_col3 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_b2a30_row10_col4 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_b2a30_row11_col1 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_b2a30_row11_col3 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# </style>
# <table id="T_b2a30">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2a30_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_b2a30_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_b2a30_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_b2a30_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_b2a30_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_b2a30_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_b2a30_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_b2a30_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2a30_level0_row0" class="row_heading level0 row0" >fixed acidity</th>
#       <td id="T_b2a30_row0_col0" class="data row0 col0" >4898.000000</td>
#       <td id="T_b2a30_row0_col1" class="data row0 col1" >6.854788</td>
#       <td id="T_b2a30_row0_col2" class="data row0 col2" >0.843868</td>
#       <td id="T_b2a30_row0_col3" class="data row0 col3" >3.800000</td>
#       <td id="T_b2a30_row0_col4" class="data row0 col4" >6.300000</td>
#       <td id="T_b2a30_row0_col5" class="data row0 col5" >6.800000</td>
#       <td id="T_b2a30_row0_col6" class="data row0 col6" >7.300000</td>
#       <td id="T_b2a30_row0_col7" class="data row0 col7" >14.200000</td>
#     </tr>
#     <tr>
#       <th id="T_b2a30_level0_row1" class="row_heading level0 row1" >volatile acidity</th>
#       <td id="T_b2a30_row1_col0" class="data row1 col0" >4898.000000</td>
#       <td id="T_b2a30_row1_col1" class="data row1 col1" >0.278241</td>
#       <td id="T_b2a30_row1_col2" class="data row1 col2" >0.100795</td>
#       <td id="T_b2a30_row1_col3" class="data row1 col3" >0.080000</td>
#       <td id="T_b2a30_row1_col4" class="data row1 col4" >0.210000</td>
#       <td id="T_b2a30_row1_col5" class="data row1 col5" >0.260000</td>
#       <td id="T_b2a30_row1_col6" class="data row1 col6" >0.320000</td>
#       <td id="T_b2a30_row1_col7" class="data row1 col7" >1.100000</td>
#     </tr>
#     <tr>
#       <th id="T_b2a30_level0_row2" class="row_heading level0 row2" >citric acid</th>
#       <td id="T_b2a30_row2_col0" class="data row2 col0" >4898.000000</td>
#       <td id="T_b2a30_row2_col1" class="data row2 col1" >0.334192</td>
#       <td id="T_b2a30_row2_col2" class="data row2 col2" >0.121020</td>
#       <td id="T_b2a30_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_b2a30_row2_col4" class="data row2 col4" >0.270000</td>
#       <td id="T_b2a30_row2_col5" class="data row2 col5" >0.320000</td>
#       <td id="T_b2a30_row2_col6" class="data row2 col6" >0.390000</td>
#       <td id="T_b2a30_row2_col7" class="data row2 col7" >1.660000</td>
#     </tr>
#     <tr>
#       <th id="T_b2a30_level0_row3" class="row_heading level0 row3" >residual sugar</th>
#       <td id="T_b2a30_row3_col0" class="data row3 col0" >4898.000000</td>
#       <td id="T_b2a30_row3_col1" class="data row3 col1" >6.391415</td>
#       <td id="T_b2a30_row3_col2" class="data row3 col2" >5.072058</td>
#       <td id="T_b2a30_row3_col3" class="data row3 col3" >0.600000</td>
#       <td id="T_b2a30_row3_col4" class="data row3 col4" >1.700000</td>
#       <td id="T_b2a30_row3_col5" class="data row3 col5" >5.200000</td>
#       <td id="T_b2a30_row3_col6" class="data row3 col6" >9.900000</td>
#       <td id="T_b2a30_row3_col7" class="data row3 col7" >65.800000</td>
#     </tr>
#     <tr>
#       <th id="T_b2a30_level0_row4" class="row_heading level0 row4" >chlorides</th>
#       <td id="T_b2a30_row4_col0" class="data row4 col0" >4898.000000</td>
#       <td id="T_b2a30_row4_col1" class="data row4 col1" >0.045772</td>
#       <td id="T_b2a30_row4_col2" class="data row4 col2" >0.021848</td>
#       <td id="T_b2a30_row4_col3" class="data row4 col3" >0.009000</td>
#       <td id="T_b2a30_row4_col4" class="data row4 col4" >0.036000</td>
#       <td id="T_b2a30_row4_col5" class="data row4 col5" >0.043000</td>
#       <td id="T_b2a30_row4_col6" class="data row4 col6" >0.050000</td>
#       <td id="T_b2a30_row4_col7" class="data row4 col7" >0.346000</td>
#     </tr>
#     <tr>
#       <th id="T_b2a30_level0_row5" class="row_heading level0 row5" >free sulfur dioxide</th>
#       <td id="T_b2a30_row5_col0" class="data row5 col0" >4898.000000</td>
#       <td id="T_b2a30_row5_col1" class="data row5 col1" >35.308085</td>
#       <td id="T_b2a30_row5_col2" class="data row5 col2" >17.007137</td>
#       <td id="T_b2a30_row5_col3" class="da

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# reclassifying quality

df.replace({"quality": {9: "best", 8: "best", 7: "good", 6: "good", 5: "average", 4: "Poor", 3: "poor", 2: "poor"}}, inplace=True)

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ## DATA SPLITTING

# %%
X = df.drop(columns="quality")

Y = df["quality"]

# lets scale the features

scaler = MinMaxScaler(feature_range=(0, 1))
x_scaled = scaler.fit_transform(X)



x_train, x_test, y_train, y_test = train_test_split(
    x_scaled, Y, 
    test_size=0.2,
    random_state=234,
    shuffle= True,
    stratify=Y
)

# %% [markdown]
# ## Modelling

# %%
models = {
    "Logistic Regression": LogisticRegression(),
    "SVM": RandomForestClassifier(),
    "Decision Tree": DecisionTreeClassifier(),
    "K Nearest Neighbors": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB()
}

results = {}
for model_name, model in models.items():

    print(f"Training {model_name}")
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    results[model_name] = accuracy
    print(f"{model_name} Accuracy: {accuracy}")

    # lets include confusion matrix 
    
    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.title(f"{model_name} Confusion Matrix")
    plt.show()

print("\nModel performance summary:")
for model_name, acc in results.items():
    print(f"{model_name}: {acc:.4f}")
# Out:
# Training Logistic Regression
# Logistic Regression Accuracy: 0.7081632653061225
# Training SVM
# SVM Accuracy: 0.8
# Training Decision Tree
# Decision Tree Accuracy: 0.7438775510204082
# Training K Nearest Neighbors
# K Nearest Neighbors Accuracy: 0.6887755102040817
# Training Naive Bayes
# Naive Bayes Accuracy: 0.6326530612244898
# Model performance summary:
# Logistic Regression: 0.7082
# SVM: 0.8000
# Decision Tree: 0.7439
# K Nearest Neighbors: 0.6888
# Naive Bayes: 0.6327

# %%
# lets get parameters for random forest (Best Classifier)

rf = RandomForestClassifier()
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
param_dist = {
    'n_estimators': randint(50, 200),
    'max_depth': randint(10, 20),
    'min_samples_split': (2, 10),
    'min_samples_leaf': (1, 4),
}

# %%
# tuning randomforest - Hyperparameters

param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
}

# %%
# define randomsearch

random_search = RandomizedSearchCV(
    RandomForestClassifier(random_state=234),
    param_distributions = param_grid
    


)

random_search.fit(x_train, y_train)

print(f"Best Parameters for RandomForest: {random_search.best_estimator_}")
# Out:
# Best Parameters for RandomForest: RandomForestClassifier(max_depth=30, random_state=234)

# %% [markdown]
# # Model Training (Fitting)

# %%
Best_Model = random_search.best_estimator_
cv_scores = cross_val_score(Best_Model, x_scaled, Y, cv=5)




print(f"cross-validation for RandomForest: {cv_scores}")
print(f"mean cross-validation score: {cv_scores.mean()}")
# Out:
# cross-validation for RandomForest: [0.66632653 0.65918367 0.70612245 0.70071502 0.71092952]
# mean cross-validation score: 0.6886554376602532

# %% [markdown]
# ## Evaluation

# %%
y_pred = Best_Model.predict(x_test)
print(classification_report(y_test, y_pred, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#         Poor       0.62      0.15      0.24        33
#      average       0.74      0.69      0.72       291
#         best       1.00      0.31      0.47        36
#         good       0.82      0.91      0.86       616
#         poor       1.00      0.00      0.00         4
#
#     accuracy                           0.79       980
#    macro avg       0.84      0.41      0.46       980
# weighted avg       0.79      0.79      0.78       980

# %% [markdown]
# ### saving model and scaler for backend calls (fastapi)

# %%
joblib.dump(Best_Model, "model.pkl")
joblib.dump(scaler, "scaler.pkl")

print("scaler and best model saved successfully")
# Out:
# scaler and best model saved successfully
